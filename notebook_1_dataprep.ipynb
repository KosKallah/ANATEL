# %% [markdown]
# # Dataprep para o Case da First Decision/ANATEL

# %% [markdown]
# Todo o meu código é escrito em inglês (inclusive nomes de variáveis, nomes de métodos, classes, etc.) isso elimina o "portuglês" que deriva de se usar uma linguagem com palavras reservadas em inglês e variáveis em português.
#
# Claro que, de acordo com as necessidades do local onde trabalho, esse padrão pode ser mudado.

# %% [markdown]
# ## 1. Setup

# %%
import re
import pandas as pd
import io
from tqdm import tqdm
from pipe import Pipe

# %% [markdown]
# ## 2. Aquisição dos Dados

# %% [markdown]
# A planilha original (.xlsm) não se encontra propriamente organizada em colunas, com detalhes da organização dos dados descritos abaixo:
#
#  * A coluna "A" contendo a maior parte dos dados
#  * Os dados estão separados por vírgula
#  * Alguns dos nomes de empresas possuem vírgulas
#  * Os textos descritivos de cada empresa estão entre aspas
#
#  Com isso, pode-se elaborar uma estratégia de formatação dos dados.
#
#  Inicialmente, os dados são salvos no Excel como texto simples (.txt), deixando para este notebook a tarefa de formatar os dados.
#
#  Isso facilita, também a repetibilidade dos procedimentos de formatação.

# %%
with open('Dados\\dataset.txt', 'r', encoding='utf-16') as file:
    text_data = file.readlines()

# %%
text_data[:5]
# Out:
# ['"name,description,employees,total_funding,city,subcountry,lat,lng"\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#  '"fitin,""fitin is the latest fit tech platform that provides a professional marketing and booking tool for gyms, studios, independent instructors and personal trainers. customers want a combination of \'trip advisor\' and \'groupon\', where they can read reviews, check out schedules, browse photos, and bookâ€¦all in one place. gyms and trainers want to be able to fill their classes and schedules. at fitin, we want to connect them and provide the community with a self-sustaining resource that helps everyone. with the wide variety of fitness entrepreneurs out there, we have amazing diversity in our workout options, but they are currently too difficult to find, if you donâ€™t already know where to go â€“ you need to search for hours, reach out to friends and family for referrals that may or may not be a good fit for you. we have over 700 classes already listed in our platform, and we want to be the resource that inspires canadians to just get movingâ€¦no matter what kind of class that may be!"",1.0,nan,toronto,ontario,43.700109999999995,-79.4163"\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#  '"quinditech,""our services include independent & collaborative ai-powered medical solutions and customizable ai-enabled services. our current leading projects are qskin for instant recognition of 26 types of skin diseases and epileptic seizure detection and prediction collaborated with the center hospital of university de montreal (chum). our kick-off product qskin is an ai-driven dermatologist-level app to help people instantly detect and recognize various skin diseases by simply taking a photo with their smartphones. once users upload their photos to our server, our ai algorithm returns the top three skin diseases with the highest match rate compared to our database. the app is ready to download at apple store and google play in north america since aug. 24th. besides initial recognition, qskin provides record management and treatment suggestions. for dermatologists, qskin will provide dermoscopy image analysis, automated disease report, emr management and other computer-aided diagnosis tools."",10.0,nan,montreal,quebec,45.50884,-73.58781"\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#  '"botfirst,""chatlanding is a digital chatbot platform where you can make conversational experiences for your website in under 2 minutes with pre-built templates. website visitors get instant valuable info in a beautiful experience while our product owners get valuable lead information, higher engagement and conversion in return."",1.0,nan,toronto,ontario,43.700109999999995,-79.4163"\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#  '"bravver,ai-powered army of health professionals in your pocket so you can feel better in your mind and body.,1.0,nan,quebec,quebec,46.8259601,-71.23522259999999"\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n']

# %% [markdown]
# ## 3. Limpeza e Shaping dos Dados

# %% [markdown]
# ### 3.1. Correção do CSV Mal-formado

# %% [markdown]
# A correção do CSV tem como centro um loop que passa por todas as linhas do arquivo TXT gerado a partir da planilha (exportando pelo próprio Excel), registrando todos os erros encontrados e permitindo que problemas nas linhas sejam detectados.
#
# A partir do loop, existem testes que efetivamente detectam os problemas, checagens visuais e procedimentos de correção (obviamente, os procedimentos de correção estão postos em células que precedem o loop, de forma que um problema corrigido deixa de aparecer na checagem).
#
# O processo de limpeza termina quando todos os testes ficam positivos e a inspeção visual não fornece resultados positivos para problemas.

# %% [markdown]
# A partir do fim da limpeza dos dados, resolvem-se problemas de shaping.

# %%
@Pipe
def subst(text:str, pattern, replacement, count=0, way='regex'):

    if way == 'regex':
        result = re.sub(pattern, replacement, text, count)
    elif way == 'replace':
        result = text.replace(pattern, replacement, -1 if count == 0 else count)
    else:
        raise ValueError(f'"{way}"? This is not the way.')

    return result

# %%
def correct_formatting(original_line:str):
    result = original_line.strip()

    result = (result
        | subst('\t"', '', way='replace')
        | subst('"\t', '', way='replace')
        | subst('\t+', ' ')
        | subst(' +', ' ')
        | subst(',\"+', '","', count=1)
        | subst('\"+,', '\",')
        | subst(f'[^a-zA-Z0-9",. /\_]', ' ')
        | subst('(?<!,)"(?!,)', '')
        | subst('\"\t+\"','')
        | subst('"+,', ' ",')
    )

    return result

# %%
text_data = [correct_formatting(line) for line in text_data]

# %%
header = '"' + '","'.join(text_data[0].split(',')) + '"'
header
# Out:
# '"name","description","employees","total_funding","city","subcountry","lat","lng"'

# %%
text_data[1]
# Out:
# 'fitin ","fitin is the latest fit tech platform that provides a professional marketing and booking tool for gyms, studios, independent instructors and personal trainers. customers want a combination of  trip advisor  and  groupon , where they can read reviews, check out schedules, browse photos, and book   all in one place. gyms and trainers want to be able to fill their classes and schedules. at fitin, we want to connect them and provide the community with a self sustaining resource that helps everyone. with the wide variety of fitness entrepreneurs out there, we have amazing diversity in our workout options, but they are currently too difficult to find, if you don   t already know where to go     you need to search for hours, reach out to friends and family for referrals that may or may not be a good fit for you. we have over 700 classes already listed in our platform, and we want to be the resource that inspires canadians to just get moving   no matter what kind of class that may be  ",1.0,nan,toronto,ontario,43.700109999999995, 79.4163'

# %%
# Esse é o loop que corre pelos dados alimentando uma lista de problemas e um dataframe que contém os dados.
# O dataframe gerado é o que passa pelos testes e inspeções visuais.

problems = []

indices_col = []
names_col = []
descriptions_col = []
employees_col = []
fundings_col = []
cities_col = []
subcountries_col = []
latitudes_col = []
longitudes_col = []
extracted_col = []

check_ndx = 20
check = False

for i in tqdm(range(1, len(text_data))):
#for i in tqdm(range(1, 10)):
    line = text_data[i]

    separator = ','
    quoting_enabled = True
    
    if i in [142, 2627, 3269, 11359, 11533, 11651, 17865]: # Linhas com problemas únicos ou pouco comuns que, por não fazerem parte do target, serão apenas desconsideradas. Esses números de linha não mudam, pois vem do arquivo exportado do .xlsm, que eu não vou tocar.
        continue

    try:
        line = line.strip()

        if check and i == check_ndx:
            print(f'BEFORE >> {line}')

        test_line = line[1:]
        if not (',"' in test_line): # Solução para o problema simples de linhas de CSV em estilo quoted/non-quoted (o primeiro caractere é forçado a ser sempre um quote mark)
            line = test_line.replace('"', '')
            quoting_enabled = False

        if check and i == check_ndx:
            print(f'AFTER >> {line}')
            print(f'QUOTED >> {quoting_enabled}')

        text = '\n'.join([header] + [line])

        if check and i == check_ndx:
            print(f'TEXT >> \n{text}')

        stream = io.StringIO(text)

        extracted = pd.read_csv(stream, sep=separator, quoting=quoting_enabled, quotechar='"').to_dict('list') # Converter o dado em DataFrame ajuda a garantir ao menos que a linha do CSV está bem formada.

        if check and i == check_ndx:
            print(f'EXTRACTED >> {extracted}')

    except Exception as err:
        problem = {
            'row': i
            ,'line': line
            ,'full_line': text
            ,'message': err
            ,'extracted': extracted
        }

        problems.append(problem)

        continue
    
    indices_col.append(i)
    names_col.append(extracted['name'][0])
    descriptions_col.append(extracted['description'][0])
    employees_col.append(extracted['employees'][0])
    fundings_col.append(extracted['total_funding'][0])
    cities_col.append(extracted['city'][0])
    subcountries_col.append(extracted['subcountry'][0])
    latitudes_col.append(extracted['lat'][0])
    longitudes_col.append(extracted['lng'][0])
    extracted_col.append(extracted) # Essa coluna temporária contém o dado em texto do qual foi criada cada linha e serve como referência para a detecção da causa raíz de cada problema.

prob = pd.DataFrame(problems)
prob.head()
# Out:
# 100%|██████████| 21299/21299 [00:33<00:00, 627.73it/s]
# Empty DataFrame
# Columns: []
# Index: []

# %%
if len(prob) > 0:
    prob.loc[0] # Para ajudar a visualizar o primeiro problema.

# %%
data = pd.DataFrame()

data['Index'] = indices_col
data['Name'] = names_col
data['Description'] = descriptions_col
data['Employees'] = employees_col
data['Funding'] = fundings_col
data['City'] = cities_col
data['Subcountry'] = subcountries_col
data['Latitude'] = latitudes_col
data['Longitude'] = longitudes_col
data['Extracted'] = extracted_col

data.head()
# Out:
#    Index          Name                                        Description  \
# 0      1       fitin "  fitin is the latest fit tech platform that pro...
# 1      2  quinditech "  our services include independent   collaborati...
# 2      3    botfirst "  chatlanding is a digital chatbot platform wher...
# 3      4        ravver  ai powered army of health professionals in you...
# 4      5     stylify "  stylify is a mobile platform that connects peo...
#
#    Employees Funding      City Subcountry  Latitude  Longitude  \
# 0        1.0     NaN   toronto    ontario  43.70011  79.416300
# 1       10.0     NaN  montreal     quebec  45.50884  73.587810
# 2        1.0     NaN   toronto    ontario  43.70011  79.416300
# 3        1.0     NaN    quebec     quebec  46.82596  71.235223
# 4        1.0     NaN   toronto    ontario  43.70011  79.416300
#
#                                            Extracted
# 0  {'name': ['fitin "'], 'description': ['fitin i...
# 1  {'name': ['quinditech "'], 'description': ['ou...
# 2  {'name': ['botfirst "'], 'description': ['chat...
# 3  {'name': ['ravver'], 'description': ['ai power...
# 4  {'name': ['stylify "'], 'description': ['styli...

# %%
data.loc[9147, 'Description']
# Out:
# 'n  97 is an e commerce store that provides customers with looks inspired off the runway with an affordable price tag.'

# %% [markdown]
# ### 3.2. Correção das Colunas Numéricas

# %% [markdown]
# Aqui temos testes automatizados que detectam problemas na conversão de dados numéricos para seus tipos adequados.
# As linhas que aparecem no dataframe de teste são as que tem problemas, portanto um dataframe vazio é um teste bem-suscedido.

# %%
data['test'] = pd.to_numeric(data['Employees'], errors='coerce')
data[(data['test'].isna()) & (data['Employees'].notna())]
# Out:
# Empty DataFrame
# Columns: [Index, Name, Description, Employees, Funding, City, Subcountry, Latitude, Longitude, Extracted, test]
# Index: []

# %%
data['Funding'] = data['Funding'].str.replace('"', '')
data['Funding'] = data['Funding'].str.replace(',', '')


data.loc[data['Funding'] == ' ','Funding'] = None
data['Funding'] = data['Funding'].astype(float)

# %%
data['test'] = pd.to_numeric(data['Funding'], errors='coerce')
data[(data['test'].isna()) & (data['Funding'].notna()) & (data['Funding'] != ' ')]
# Out:
# Empty DataFrame
# Columns: [Index, Name, Description, Employees, Funding, City, Subcountry, Latitude, Longitude, Extracted, test]
# Index: []

# %%
data['test'] = pd.to_numeric(data['Latitude'], errors='coerce')
data[(data['test'].isna()) & (data['Latitude'].notna())]
# Out:
# Empty DataFrame
# Columns: [Index, Name, Description, Employees, Funding, City, Subcountry, Latitude, Longitude, Extracted, test]
# Index: []

# %%
data['test'] = pd.to_numeric(data['Longitude'], errors='coerce')
data[(data['test'].isna()) & (data['Longitude'].notna())]
# Out:
# Empty DataFrame
# Columns: [Index, Name, Description, Employees, Funding, City, Subcountry, Latitude, Longitude, Extracted, test]
# Index: []

# %%
data.drop(columns='test', inplace=True)

# %% [markdown]
# ### 3.3. Correção das Colunas de Texto

# %% [markdown]
# As colunas de texto são limpas a partir de inspeção visual, usando o "scrollable element" sempre que necessário.

# %%
data['Name'] = data['Name'].str.replace('"', '')
data['Name'] = data['Name'].str.replace('_', '')

# %%
list(data['Name'])
# Out:
# ['fitin ',
#  'quinditech ',
#  'botfirst ',
#  'ravver',
#  'stylify ',
#  'peloton technologies ',
#  'weave travels ',
#  'space   york university',
#  'glaucus.ai ',
#  'magnifi ',
#  'eara technologies ',
#  'amika   homecare ',
#  'alitheia technologies ',
#  'justgotthat  ',
#  'bundle rewards ',
#  'nugget.ai ',
#  'titanfile ',
#  'candor ai ',
#  'velocia ',
#  'soundpays ',
#  'market iq ',
#  'valtools company',
#  'n via education',
#  'trustunion ',
#  'passionfruit ',
#  'arz',
#  'the original smiths ',
#  'zighra ',
#  'edify learning spaces ',
#  'jauntin  ',
#  'mapyourproperty ',
#  'motive health ',
#  'thornhill medical ',
#  'way2go apps inc.  ',
#  'thedatabridge.org ',
#  'precision biomonitoring ',
#  'testtoad ',
#  'west immigration consulting ',
#  'leo prestte ',
#  'locatemotion ',
#  'ittelstand finanical',
#  'fleeky ',
#  'coiniq ',
#  'izademy.com',
#  'learnademy.com ',
#  'buddi ',
#  'modenala automotive sp ',
#  'rally ',
#  'sitwidse0ul by h y ',
#  'roluton depot 250 mg',
#  'giver.be ',
#  'abanban ',
#  'ntrepreneurship ubc',
#  'ophelia financial technologies ',
#  'ipnos ',
#  'the value builder system ',
#  'chkout ',
#  'holland industry toronto  ',
#  'mukmuk cloud services ',
#  'bloksec ',
#  'cookie buzz ',
#  'cobbl ',
#  'runner ',
#  'dgehealth',
#  'r g strategic ',
#  'the well   creative consultants ',
#  'ribute kiosk',
#  'bonac innovation ',
#  'sun dryd studios ',
#  'international ultrasonic technologies  ',
#  'fraction technologies ',
#  'r d partners ',
#  'ncoil',
#  'seamlessmd ',
#  'harness biotechnology ',
#  'movelytics ',
#  'faucets bitcoin',
#  'oar',
#  'ad lounge ',
#  'shop and shout ltd.  ',
#  'sumoquote ',
#  'semanti.ca ',
#  'resaas ',
#  'puremark ',
#  'idementi ',
#  'menuthat ',
#  'help  we ve got kids ',
#  'lickety link ',
#  'infin  ',
#  'rewardful ',
#  'astenridge',
#  'talncy ',
#  'tv overstock ',
#  'espress labs ',
#  'equallyt ',
#  'dadj ',
#  'grain discovery ',
#  'go oil canada ',
#  'guestlogix ',
#  'popstyle app ',
#  'amy inspired ',
#  'swirltex  ',
#  'xcilia',
#  'flourish ',
#  'specialvr ',
#  'swob ',
#  'agorize ',
#  'agile humanities agency ',
#  'pink elephant marketing ',
#  'sonnet labs ',
#  'belgravia solutions ',
#  'ekamp',
#  'modtod ',
#  'dealmaker ',
#  'cannabis data science  ',
#  'flock audio ',
#  'advanced analytics and research lab ',
#  'iversio',
#  'linked boosts ',
#  'distributek ',
#  'lashitdelivery',
#  'durabyte ',
#  'blue panda digital ',
#  'paavaa ',
#  'beo ',
#  'urban boutique technologies ',
#  'coral health research   discovery ',
#  'scheddoo ',
#  'vinci labs ',
#  'proof ',
#  'reliablyme ',
#  'monk society ',
#  'liscena ',
#  'betterworth ',
#  'carto ',
#  'iply',
#  'rubikon blockchain ',
#  'bate.co',
#  'hanalytics solutions ',
#  'novalte ',
#  'bootkik ',
#  'raft delivery',
#  'gabbi.ai ',
#  'bedbugs films ',
#  'kds medical eng.   div. space health ',
#  'driftscape ',
#  'c laboratories',
#  'member365 ',
#  'demand metric ',
#  'picotera electronics inc.  ',
#  'brens north america ',
#  'daakor ',
#  'pdftron systems ',
#  'burnerwater ',
#  'bubbles software ',
#  'benji ',
#  'the other dimension 52 ',
#  'eventdesk ',
#  'pitchupp ',
#  'totum tech ',
#  'ivirtual technologies ',
#  'alphatron technology ',
#  'picture this 3d ',
#  'real3games ',
#  'merit airport taxi ',
#  'sirp ',
#  'mindshare technologies inc o/a magnifi ',
#  'wysed ',
#  'team bank ',
#  'kolony robotic  ',
#  'sparcblock ',
#  'global websoft techno ',
#  'driveher transportation  ',
#  'coinscious ',
#  'fera',
#  'immons sharpe',
#  'tazwiz ',
#  'd.s services ',
#  'rooms app ',
#  'control  ',
#  'aegis shift ',
#  'sheerchain ',
#  'phase advanced sensor systems ',
#  'paybright ',
#  'mc3 sentient  ',
#  'daypack ',
#  'builderbase ',
#  'lackjack sports',
#  'fable tech labs ',
#  'medfar solutions cliniques ',
#  'zeroone.ai ',
#  'nobul ',
#  'vania art   design ',
#  'the upside foundation of canada ',
#  'finishitt ',
#  'edn',
#  'tricerta consulting ',
#  'browns dairy farms canada ',
#  'faxbb ',
#  't u 1ef1  cai thu u 1ed1 c l   ',
#  'the volleyball centre ',
#  ' marketing professionals',
#  'rotating ',
#  'oloursmith',
#  'ecoservice group ',
#  'belle   belly ',
#  'uantfury',
#  'hatchways ',
#  'haven ',
#  'cubic movie ',
#  'dr. robert axelrad dental office ',
#  'bucketlist rewards ',
#  'avidbots ',
#  'singularity vr ',
#  'altcare   alternative medicine ',
#  'king s framing   art gallery ',
#  'mpossible web design',
#  'odyssey ',
#  'werkapp ',
#  'target trading ',
#  'brendon mcnaughton inc.  ',
#  'headquarters ',
#  'iris r d ',
#  'sapphire limousine ',
#  'homit ',
#  'ymomentum',
#  'intible',
#  'upchain ',
#  'tlasai',
#  'whisqr customer engagement ',
#  'tryon technology ',
#  'nfinite growth',
#  'aquova ',
#  'leadfox techonologie ',
#  'rooflite',
#  'mississauga tow truck ',
#  'betteryet rewards ',
#  'onnect',
#  'mortgage sandbox ',
#  'kipp technologies',
#  'booking automation ',
#  'data kettle ',
#  'hackergal ',
#  'vcancy ',
#  'hoktus ',
#  'principle ai ',
#  'mecka ',
#  'infield id  ',
#  'rtie',
#  'bougie baby ink  ',
#  'dwelly ',
#  'ordr.ai ',
#  'stockenja ',
#  'drenalin motors',
#  'wisdom ',
#  'emotors direct ',
#  'robbox  ',
#  'icruity',
#  'bjr movement ',
#  'vital medical group ',
#  'simbi ',
#  'conic security ',
#  'roundhog',
#  'modern mop facility services inc.  ',
#  'kn  x ',
#  'pools ',
#  'nuage ',
#  'tolindo deliveries ',
#  'roomlend ',
#  'mbold',
#  'restify',
#  'achieve online ',
#  'right immigration',
#  'clientflo ',
#  'reversesale ',
#  'hackworks ',
#  'houspro ',
#  'whitelist0x ',
#  'goldspot discoveries ',
#  'latero labs ',
#  'lyndex technology ',
#  'rfqnet ',
#  'trozzo trees   care ',
#  'ircle cardiovascular imaging',
#  'think tank innovations  sharesmart  ',
#  'ktlist ',
#  'verus ',
#  'advanced alternative investment systems ',
#  'skin junk ',
#  'hygge lagom ',
#  'nsurdinary',
#  'myxp app  ',
#  'ueat.io ',
#  'cleartally ',
#  'qspice labs ',
#  'envision it services ',
#  'ressurewashr',
#  'tivitas interactive ',
#  'mpirical automation',
#  'bizskills academy inc.  ',
#  'daisy intelligence ',
#  'cyno ',
#  'mmunitor',
#  'wowa leads ',
#  'paypie ',
#  'anzil capital',
#  'rdi lab',
#  'positive venture group ',
#  'eedo',
#  'flower   freedom ',
#  'mesomat ',
#  'oridor.io',
#  'eamsly',
#  'buddhi bistro ',
#  'protect yu ',
#  'strainprint technologies ',
#  'mydoni  ',
#  'stableunit ',
#  'bluink  ',
#  'quotetome ',
#  'ctrlgate ',
#  'owl technologies ',
#  'enowaze',
#  'eatibl   dynamic pricing for restaurants ',
#  'steroid aim',
#  'techversant canada ',
#  'etwhitepalm',
#  'fibrenew east kootenays ',
#  'korechi innovations ',
#  'willful ',
#  ' but',
#  'basescore ',
#  'optimal efficiency ',
#  'tesera systems ',
#  'learpath robotics',
#  'global catalog ',
#  'bare ',
#  'lasso',
#  'stashed ',
#  'delve global ',
#  'english forward ',
#  'freshworks studio ',
#  '10408484 canada incorporated  hiride  ',
#  'eugeria ',
#  'renuvo',
#  'memoryz ',
#  'doco ',
#  'bitnobi ',
#  'optical illusion museum ',
#  'bites mealshare ',
#  'elastic storage solutions ',
#  'nox bridge college',
#  'first mountain ',
#  'sar capital',
#  'the workaround ',
#  'abacus ',
#  'delfy ',
#  'adputer ',
#  'olive ',
#  ' dual biometrics',
#  'aba access ',
#  'gimme360 ',
#  'fansaves ',
#  'rival technologies ',
#  'vancosys data security ',
#  'trust caregivers ',
#  'affecting change ',
#  'urgical solution',
#  'jmj medical ',
#  'edtekhive  ',
#  '3milliondogs  ',
#  'industrial ventures connect ',
#  'headache sciences ',
#  'crescendo  ',
#  'timechain ',
#  'crescendo   inclusive workplaces ',
#  'retainify ',
#  'hiredhippo ',
#  'easytransfer ',
#  'raas ',
#  'minipay ',
#  'fringefm ',
#  'digiplay ',
#  'he life house group',
#  'toryflow',
#  'annogo ',
#  'aqua air 247  ',
#  'airdesk',
#  'creditgenie ',
#  'killify',
#  'bumble bloom ',
#  'product manager jobs ',
#  'blocksyte ',
#  'yervana ',
#  'skycap financial ',
#  'azoo',
#  'project 33 ',
#  'taproot edmonton ',
#  'business alliance consulting ',
#  'practica  ',
#  'essntials co ',
#  'zip it hippie ',
#  'seafuture sustainable biotech ',
#  'linkmentalhealth ',
#  'realoffice360 ',
#  'rbc reach ',
#  'black veil bridal weddings and events  ',
#  'licc',
#  'byos ',
#  'nano 3 labs ',
#  'nightline ',
#  'ehire solutions',
#  'travel paper scissors ',
#  'on purpose projects ',
#  'human in motion ',
#  'creativity digital ',
#  'oombo ',
#  'tangerines ',
#  'lumiere vr ',
#  'tqc developments ',
#  'playing bot ',
#  'c tribe society ',
#  'open screenplay ',
#  'mple',
#  'klippers ',
#  'daonari ',
#  'brbwall ',
#  'u 0645  u 062a  u 062c  u 0631  u 064a  ',
#  'quantified citizen ',
#  'softdrive ',
#  'lphaio',
#  'cuore ',
#  'eos canada ',
#  'focustime technologies ',
#  'legal innovation zone ',
#  'agecoins',
#  'richard robbins  ',
#  'greenstream networks ',
#  'canna center ',
#  'paperleaf ',
#  'wagex ',
#  'league ',
#  'launch0x ',
#  'three pub ',
#  'hitmetrics ',
#  'alcohol2me ',
#  'plasma capital ',
#  'the car salon autobody ',
#  'addbrain ',
#  'unnelytics',
#  'reevolt orange county',
#  'uto ',
#  'myzone media ',
#  '4rogue media ',
#  'lite',
#  'johnny brown ',
#  'goods and commerce ',
#  'humaniti ',
#  'calvin barry professional ',
#  'comuet technologies ',
#  'mrt tec',
#  'urple sales solutions ',
#  'golden line green care ',
#  'bgx ',
#  'smc group ',
#  'stackraft ',
#  '21q ',
#  'pickee  working title  ',
#  'via advanced technologies ',
#  'saf systems ',
#  'local search heroes  ',
#  'propulsio 360   business consultants ',
#  'cleanphd ',
#  'votrux',
#  'blackberry ',
#  'anteater analytics ',
#  'petradise ',
#  'ybuy ',
#  'eneral meade company',
#  'xtreme blockchain labs ',
#  'enlive labs   therapy recovery for all ',
#  'ulula ',
#  'andlord web solutions',
#  'artventure ',
#  'hollow4 entertainment ',
#  'pp growth network',
#  'emosquito ',
#  'scenarex ',
#  'phonicsvr ',
#  'lexton harper co. ',
#  'gelly ',
#  'kiran ',
#  'pro notes ',
#  'platform development group ',
#  'makespace group ',
#  'gamer relay ',
#  'black hawk ',
#  'matador network ',
#  'optiko eyewear ',
#  'buy geftinat 250 mg ',
#  'euraxio',
#  'causebox enterprises ',
#  'coinsmart ',
#  'strongbody apparel ',
#  'getmint ',
#  'vehicle mind technologies ',
#  'stense',
#  'handiy ',
#  'donaldson   james ',
#  'ceremony travel ',
#  'aaa waterproofing   etobicoke basement ',
#  'urbanshelter ',
#  'computer hardware sales ',
#  'project  human city ',
#  'contentfly ',
#  'eeple',
#  'cs noble',
#  'bitontop technologies ',
#  'krypto ',
#  'breez workforce management ',
#  'kerr properties ',
#  'snapclarity ',
#  'lendingmate ',
#  'free studio ',
#  'aaron esteban ',
#  'nesto ',
#  'javelin sports ',
#  'exio ',
#  'nobul ',
#  'mike mihelic ',
#  'nterior beverages',
#  'lash delivr',
#  'imtraining ',
#  'eepmontreal',
#  'frutose cosmetics ',
#  'sai dham canada ',
#  'easi',
#  'coinberry ',
#  'rend savvy',
#  'reen notes co',
#  'new homes condos ',
#  'ynergy guinee',
#  'ratebroker canada ',
#  'corporate finance institute ',
#  'wavelite ',
#  'servall development ',
#  'advance clinic solutions ',
#  'torneo sb ',
#  'ford plastic surgery ',
#  'dronemates ',
#  'estateably ',
#  'caera health ',
#  'wabes digital marketing agency ',
#  'ankhealth ',
#  'ybos design studio',
#  'vibes ',
#  'dentistry on finch ',
#  'mycarebase solutions ',
#  'buildup ',
#  'ruba',
#  'newtrax technololgies ',
#  'gohyper ',
#  'organoid ',
#  'genesis land surveying ',
#  'waypointar ',
#  'luxie.io ',
#  'studentguide ',
#  'mavennet ',
#  'steroided ',
#  'arrive ',
#  'ave on amazon',
#  'the lake project ',
#  'college of pharmacists of bc ',
#  'ini health',
#  'hanmao',
#  'ealthblock identity',
#  'advanced inclusive technology  ',
#  'pearfiction studios ',
#  'nextech ar solutions ',
#  'simple. ',
#  'ringitfast',
#  'symetria ',
#  'ilobby  ',
#  'snug underwear ',
#  'rise people ',
#  'reitium  ',
#  'bindrop ',
#  ' ',
#  'crave agency ',
#  'alentseed',
#  'biorender ',
#  'lunia ai ',
#  'mbmc productions ',
#  'amrezo mobile development ',
#  'digital shovel ',
#  'kabn ',
#  'hardboot communications ',
#  'aitken robertson criminal lawyers ',
#  'open people network ',
#  'aqomi ',
#  'he sight',
#  'gsr studio ',
#  'he unconventional life',
#  'cannabis clinics of ontario ',
#  'healthy alternative ',
#  'extract magazine ',
#  'paul godlewski ',
#  'optimiselab ',
#  'inti aerospace ',
#  'dunbar ',
#  'r concierge services ',
#  'frettable ',
#  'nazca ',
#  'west vancouver pest control ',
#  'discover footage ',
#  'enoch technologies ',
#  'wm loss prevention services',
#  'iospective',
#  'adaptcore health ',
#  'caredfor ',
#  'premier heating   cooling ',
#  'barakat accounting services ',
#  'high tech appliance repair toronto ',
#  'abacus financial ',
#  'r architectural visualizations',
#  'capital architecture   development ',
#  'ixtimate',
#  'butler ',
#  'crowdstride ',
#  'pandacar ',
#  'maxisong ',
#  'retreatify ',
#  'vacation rentals experts ',
#  'floridatv ',
#  'lovefresh ',
#  'epic blockchain technologies ',
#  'ritz carlton hotel canada ',
#  'aphax',
#  'crtv con ',
#  'macrolab ',
#  'foxquilt ',
#  'smops ',
#  'calvin barry professional lawyer ',
#  'eaturemine',
#  'the rainmaker enterprise ',
#  'urbandash ',
#  'binners junk removal ',
#  'tory jarvis   co. ',
#  'nonfungible ',
#  'cobubble ',
#  'ision plumbing   heating',
#  'deliverr ',
#  'jussapplaud ',
#  'all guys free',
#  'modern home furniture ',
#  'iftedone records',
#  'beenthere  ',
#  'lobalive technology',
#  'student athlete academy ',
#  'coutingtree',
#  'ostly danish',
#  'quest ',
#  'ovis',
#  'imelight software',
#  'empire marketing ',
#  'lockluxe network',
#  'chef connie ',
#  'odern purair vancouver',
#  'hikr ',
#  'arianne relocation canada ',
#  'light studio ',
#  'homicity ',
#  'chattrack ',
#  'toronto tastemakers ',
#  'jupiter vision ',
#  'tqc concrete ',
#  'malone tuning ',
#  'ugotrendy ',
#  'lockluxe',
#  'opencare ',
#  'marlene desousa ',
#  'aerialytic ',
#  'fieldchat ',
#  'canadas best flooring ',
#  'jojo technology solutions ',
#  'hat i got',
#  'bespoke technologies ',
#  'xerox printer support canada ',
#  'dax technologies ',
#  'phyven medicinal cannabis dispensary ',
#  'oranj fitness kensington ',
#  'idnit',
#  'vibravid ',
#  'rickstart',
#  'i.can.tech club ',
#  'pivohub ',
#  'bitcoin bay ',
#  'link mortgage',
#  'cigo tracker ',
#  'universe events ',
#  'verifyed.com ',
#  'rc trading ',
#  'together ',
#  'neweb labs ',
#  'snaphud ',
#  'menzies aviation ',
#  'leap tools ',
#  'sopho ',
#  'brew ninja ',
#  'carbon free collective ',
#  'govhubs ',
#  'alt 1 crypto exchange ',
#  'gigalab technologies ',
#  'to3',
#  'rtcx ',
#  'ns',
#  'terra floor plans ',
#  'cozymir ',
#  'ecbasics',
#  'cuboh ',
#  'rawlin ',
#  'sureway digital mall  ',
#  'prise',
#  'abritu sport ',
#  'play exchange ',
#  'only child apparel ',
#  'learnedly ',
#  'upscale technology ',
#  'hainpay',
#  'splend ',
#  'colab software ',
#  'lipit',
#  'tax 911 now ',
#  'convertus ',
#  'blockmaintain ',
#  'uxy hair',
#  'bundts of steel ',
#  'ou shop for me',
#  'docsie.io ',
#  'nmind technologies',
#  'flavourlabs ',
#  'c p dental lab ',
#  'adverbs group ',
#  'inner apps ',
#  'eventmobi ',
#  'buy tadarise oral jelly ',
#  'cash advance ottawa ',
#  'ibbrjabber',
#  'wicket ',
#  'sinitic ',
#  'streettext.com ',
#  'watch   ride virtual snowboard school ',
#  'feroot security ',
#  'nero technology ',
#  'walton wood farm ',
#  'nano north ',
#  'foodi canada ',
#  'omnt tech',
#  'pixelphonics  ',
#  'campnab ',
#  'spergel ',
#  'merit ',
#  'sourceoutsource ',
#  'creatubbles ',
#  'c4media ',
#  'newton ',
#  'living well counselling services ',
#  'tidal royalty ',
#  'elevate rooms ',
#  'mitigo ',
#  'flatkit ',
#  'product watch ',
#  'the visionable ',
#  'iboost zone ',
#  'lyeasy software',
#  'hypnosis toronto ',
#  'avro life science  yc w18  ',
#  'reel apps ',
#  'ampm door services ',
#  'shape immersive ',
#  'inputkit ',
#  'cheap travel calendar ',
#  'corrupt ms access file ',
#  'carus productions ',
#  'ogr',
#  'onestep studios ',
#  'quake ecms ',
#  'strata engineering ',
#  'vamax group',
#  'uhms  ',
#  'nvivo ai',
#  'cabrera technologies ',
#  'etro.digital',
#  'seam technic ',
#  'evolo ',
#  'elastic email ',
#  'davinci ',
#  'mercku ',
#  'tally interactive ',
#  'ucky ganes',
#  'airos crypto ',
#  'geocode.xyz ',
#  'yz iglobal',
#  'addiction british columbia ',
#  'addiction ontario ',
#  'softcrowds ',
#  'pockethealth ',
#  'packetmining ',
#  'lane cycle ',
#  'elt technologies',
#  'dr. peter lennox ',
#  'bluescout ',
#  'ello vincent',
#  'booker ',
#  'zsec',
#  'zanq  ',
#  'kinoo  ',
#  'inteqna ',
#  'saltedge ',
#  '0 dollar drafting .com',
#  'cm technologies ',
#  'photon etc. ',
#  'cannabis b2b network web directory ',
#  'wissborg',
#  'brnt designs ',
#  'insertly ',
#  'payup jack ',
#  'ajrn ',
#  'foursixty ',
#  'continuum software solutions ',
#  'flux capital ',
#  'docscan.io ',
#  'bohr 8 ',
#  'desmarais group ',
#  'hireup canada ',
#  'opi ',
#  'ubahaus',
#  'it technologies',
#  'ur baby project',
#  'steam energy labs ',
#  'workhorsehub ',
#  'tech help canada ',
#  'realshare ',
#  'blockmd ',
#  'eaut ',
#  'medi trace  ',
#  'kasventures ',
#  'tandx ',
#  'ivsmart group',
#  'cbi2 capital ',
#  'berkeley dental ',
#  'neuron ',
#  'atlas tools   machinery ',
#  'startup slang ',
#  'volentix labs ',
#  'rosa lives here ',
#  'repshift ',
#  'ellie ',
#  'toms bits',
#  'riipen ',
#  'beam.city ',
#  'quaintance ',
#  'terminal ',
#  'torque consulting ',
#  'pique ventures ',
#  ' mine technologies',
#  'onviolent',
#  'bidali ',
#  'lean consulting ',
#  'ebbit',
#  'comprima ',
#  'draper ai ',
#  'picovoice ',
#  'cvstms ',
#  'nissa seych music ',
#  'mast hair  ',
#  'workbox ',
#  'cloudraker ',
#  'obadx',
#  'opisystems ',
#  'ackground check',
#  'triton canada ',
#  'to 9 to 5 ',
#  'kiwirh ',
#  'moca auto body estimator ',
#  'evolution lightfield labs ',
#  'nostartup',
#  'unch',
#  'pledgeshots ',
#  'unchbreak',
#  'siglarr viking naturals ',
#  'servicebystudent ',
#  'give a seat ',
#  'nomad cre8tive ',
#  'craft beer passport ',
#  'swift medical ',
#  'toko ',
#  'hp printer technical support canada ',
#  'chez dine  ',
#  'proxybus ',
#  'visionclerk ',
#  'ko  os intelligence ',
#  'sitevue ',
#  'strong women association ',
#  'snapsize ',
#  'intventures ',
#  'rossul  ',
#  'aurora analytical ',
#  'venngo ',
#  'creationauts ',
#  'ooks that grow',
#  'realevate ',
#  'neuralseg ',
#  'caterio ',
#  'delphia ',
#  'obsy',
#  'brokrete ',
#  'fortran traffic systems ',
#  'instein exchange',
#  'stretech ',
#  'odis',
#  'hatbestincanada',
#  'grow ',
#  'openreg ',
#  'andure',
#  'deeplite ',
#  'workali ',
#  'fragment exp  rience ',
#  'easyflash ',
#  'growpayment ',
#  'arageforrent.ca',
#  'smartcane ',
#  'boxknight ',
#  'ttjo ',
#  'wfg ',
#  'thejpl.co ',
#  'simpleisenough ',
#  'socializd ',
#  'sprout ',
#  'iops',
#  'tallion express',
#  'baby doppler ',
#  'seatone ',
#  'bhumprak ',
#  'veritas.supply ',
#  'cdax ',
#  'leadertags ',
#  'remedium ai ',
#  'health4myself ',
#  'nimbus tutoring ',
#  'playme ',
#  'swae ',
#  'neevinternational surveyors pmc n epc ',
#  'connective ',
#  'edibly ',
#  'alloon labs',
#  'andm digital agency',
#  'vent spaces',
#  'context public messaging ',
#  'kaleidosports ',
#  'muve ',
#  'areguide',
#  'enith',
#  'ayzpot',
#  'socialight products ',
#  'colonial square inn   suites ',
#  'peersight ',
#  'basilisk ',
#  'aura cannabis ',
#  'railway labs ',
#  'trust recruitment consultant ',
#  'alinea ',
#  'breathe life ',
#  'silofit ',
#  'osmos cloud ',
#  'prologue to the performing arts ',
#  'pfield solutions',
#  'toronto arts foundation ',
#  'ellution',
#  'potential ',
#  'innavera ',
#  'phyxable ',
#  'smart hollow entertainment ',
#  'enkidoo.ai ',
#  'bteducation  ',
#  'city centre dance ',
#  '4amps technologies ',
#  'coinbio  ',
#  'covault technologies ',
#  'chainsafe systems ',
#  'chatler ',
#  'eventful upbringings ',
#  'autoaerials ',
#  'unicorn dojo ',
#  'cognitivechem  stealth  ',
#  'click less do more ',
#  'lifepoints ',
#  'butter ',
#  'pursuit ',
#  'accessar ',
#  ...]

# %%
data['City'].unique()
# Out:
# array(['toronto', 'montreal', 'quebec', 'victoria', 'markham', 'kelowna',
#        'vancouver', 'waterloo', 'ottawa', 'calgary', 'guelph', 'winnipeg',
#        'burlington', 'halifax', 'edmonton', 'vaughan', 'whitehorse',
#        'london', 'fredericton', 'chicoutimi', 'kitchener', 'sudbury',
#        'mississauga', 'north york', 'richmond hill', 'brampton',
#        'abbotsford', 'charlottetown', 'galiano island', 'sherbrooke',
#        'kingston', 'beaumont', 'sylvan lake', 'richmond', 'barrie',
#        'st. john s', 'milton', 'laval', 'sherwood park', 'cranbrook',
#        'oshawa', 'saint jean sur richelieu', 'cornwall', 'saskatoon',
#        'cambridge', 'saint john', 'boston creek', 'nelson', 'cochin',
#        'princeville', 'etobicoke', 'langley', 'blainville', 'scarborough',
#        'oakville', 'strathroy', 'longueuil', 'regina',
#        'whitchurch   stouffville', nan, 'coquitlam', 'surrey',
#        'niagara falls', 'kamloops', 'okotoks', 'duncan', 'chatsworth',
#        'tecumseh', 'west vancouver', 'lucknow', 'smiths falls',
#        'spruce grove', 'windsor', 'moncton', 'peterborough', 'paris',
#        'newmarket', 'port coquitlam', 'houston', 'burnaby',
#        'fort mcmurray', 'st. catharines', 'penticton', 'glendon',
#        'okanagan centre', 'west end', 'truro', 'sault ste. marie',
#        'tillsonburg', 'apsley', 'bromont', 'dartmouth', 'morrisburg',
#        'timmins', 'reston', 'sydney', 'pierrefonds', 'grande prairie',
#        'orleans', 'canmore', 'kimberley', 'delta', 'brazil lake',
#        'trois rivieres', 'osoyoos', 'shawinigan',
#        'bradford west gwillimbury', 'caledon', 'perth', 'alexandria',
#        'lindsay', 'whistler', 'delhi', 'collingwood', 'kirkland',
#        'parksville', 'corner brook', 'airdrie', 'red deer', 'chester',
#        'avenir', 'nestleton station', 'port colborne', 'wolfville',
#        'pickering', 'bowmanville', 'madawaska', 'nanaimo', 'fox creek',
#        'boucherville', 'saint eustache', 'verdun', 'williams lake',
#        'whitby', 'northridge', 'german mills', 'watford', 'gatineau',
#        'selkirk', 'st. vincent s st. stephen s peter s river',
#        'lethbridge', 'chambly', 'bedford', 'smooth rock falls',
#        'cordova bay', 'brantford', 'north saanich', 'saint sauveur',
#        'brighton', 'campbell river', 'saguenay', 'lloydminster',
#        'stewiacke', 'aurora', 'castlegar', 'thunder bay', 'midland',
#        'edson', 'north bay', 'prince george', 'port alberni',
#        'winsloe south', 'new mexico', 'londesborough', 'fletchers lake',
#        'welland', 'lanark', 'miramichi', 'owen sound', 'medicine hat',
#        'grandes piles', 'summerland', 'levis', 'peachland', 'terrebonne',
#        'alberton', 'chatham', 'fort frances', 'golden',
#        'clarence rockland', 'maple ridge', 'chilliwack', 'napanee',
#        'langdon', 'brandon', 'gananoque', 'coaldale', 'sarnia',
#        'plessisville', 'clairmont', 'woodstock', 'bathurst',
#        'britannia heights', 'stratford', 'kensington market', 'steinbach',
#        'vernon', 'forestville', 'masson angers', 'saint jerome',
#        'cochrane', 'devon', 'essex', 'renfrew', 'orangeville',
#        'courtenay', 'sackville', 'liverpool', 'leamington', 'francis',
#        'cobourg', 'ayr', 'granby', 'red earth', 'altona', 'jasper',
#        'yellowknife', 'caledon east', 'prince albert', 'black diamond',
#        'lunenburg', 'kenora', 'camrose', 'coboconk', 'belleville',
#        'killarney', 'thessalon', 'invermere', 'saint hyacinthe',
#        'quesnel', 'shediac', 'stayner', 'amherstburg', 'wheatley',
#        'kemptville', 'sundre', 'miami', 'jacksonville', 'new westminster',
#        'hague', 'stony plain', 'alma', 'georgetown', 'ajax', 'sebright',
#        'st. albert', 'happy valley goose bay', 'prince rupert',
#        'st. jacobs', 'st. thomas', 'new hazelton', 'kilcoo camp',
#        'centreville wareham trinity', 'winfield', 'mallorytown landing',
#        'manotick station', 'st. marys', 'queensville', 'beaumaris',
#        'vineland station', 'buctouche sud', 'maitland', 'shelburne',
#        'rexdale', 'waterdown', 'saanichton'], dtype=object)

# %%
data['Subcountry'].unique()
# Out:
# array(['ontario', 'quebec', 'british columbia', 'alberta', 'manitoba',
#        'nova scotia', 'yukon', 'new brunswick', 'prince edward island',
#        'newfoundland and labrador', 'saskatchewan', nan,
#        'northwest territories'], dtype=object)

# %%
data = data[data['Name'].notna()]
data.drop(columns='Extracted', inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21289 entries, 0 to 21291
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Index        21289 non-null  int64
#  1   Name         21289 non-null  object
#  2   Description  21289 non-null  object
#  3   Employees    21289 non-null  float64
#  4   Funding      10 non-null     float64
#  5   City         21276 non-null  object
#  6   Subcountry   21276 non-null  object
#  7   Latitude     21276 non-null  float64
#  8   Longitude    21276 non-null  float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 1.6+ MB

# %% [markdown]
# ## 4. Gravação dos Dados Limpos

# %%
data.to_csv('Dados\\clean_data.csv')
